# %%
import numpy as np
from PIL import Image
import cv2
from urllib.request import urlopen

# %% [markdown]
# #### Read Image from URL

# %%
image = Image.open(urlopen("https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/800px-Python-logo-notext.svg.png"))
image = image.resize([100, 100])
image
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x2890EB814F0>

# %% [markdown]
# #### Composting and Matting

# %% [markdown]
# ##### Using PIL

# %%
bg_img = Image.open("bg_image.png").resize([200, 200])
fg_img = Image.open("fg_image.png").resize([200, 200])

fg_img.resize((100, 100))
blended_img = Image.blend(bg_img, fg_img, 0.5)
blended_img
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x2890ECD81C0>

# %% [markdown]
# ##### Using OpenCV

# %%
bg = np.array(bg_img)
fg = np.array(fg_img)
alpha = 0.7
dest = cv2.addWeighted(bg, alpha, fg, 1- alpha, 0.0)
dest = Image.fromarray(dest)
dest
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x2890ECFBAC0>
